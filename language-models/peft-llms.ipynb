# %% [markdown]
# # An Overview of PEFT methods in LLMs

# %%
# %%bash
# pip install transformers[torch]
# pip install datasets
# pip install sentencepiece
# pip install evaluate
# pip install rouge_score
# pip install peft
# pip install accelerate -U
# pip install lightning
# Out:
# ...
# Requirement already up-to-date: accelerate in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (0.27.2)
# ...

# %% [markdown]
# PEFT Methods
